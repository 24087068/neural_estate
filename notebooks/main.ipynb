# %% [markdown]
# # Project: Neural Estate
# ### Datum: 2026-03-11
# ### Team:
# ### Teamleden: Michal Kakol (24087068),

# %% [markdown]
# # 0. Imports

# %% [markdown]
# ### 0.1. Libraries:

# %%
from functions.main import *
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 0.2. Data locally:

# %%
df_train_meta, img_train, df_test_meta, img_test = load_local() # comment on/off

# %% [markdown]
# ### 0.3. Data colab:

# %%
# df_train_meta, img_train, df_test_meta, img_test = load_colab() # comment on/off

# %% [markdown]
# # 1. EDA:

# %% [markdown]
# ...

# %%
img_show(df_train_meta, img_train)

# %%
corr_show(df_train_meta)

# %% [markdown]
# # 2.  Fully-connected neuraal netwerk:

# %% [markdown]
# # 3. Convolutioneel neuraal netwerk from scratc:

# %% [markdown]
# # 4. Transfer learning:

# %% [markdown]
# # 5. Multimodaal mode:

# %% [markdown]
# # 6. Bevindingen:

# %% [markdown]
# ...

# %% [markdown]
# # 7. Conclusie en aanbevelingen:

# %% [markdown]
# ...

# %% [markdown]
# # 8. Bronnenlijst:

# %% [markdown]
# ...
